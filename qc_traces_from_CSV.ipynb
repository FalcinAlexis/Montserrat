# %% [markdown]
# This notebook is used to run some quality control on the individual waveforms and represent this as a number added to the dataframe

# %%
import pandas as pd
import csv
import obspy
import matplotlib.pyplot as plt
import numpy as np
from CheckFunctions import *
import os
import glob

# %%
# Load the catalogue
SEISAN_DATA = os.environ['SEISAN_DATA']
CSVpath = os.path.dirname(SEISAN_DATA)
os.chdir(CSVpath)
list_of_csv_files = sorted(glob.glob('MVOE_catalog*.csv'))
frames = []
for csvfile in list_of_csv_files:
    thisframe = pd.read_csv(csvfile)
    frames.append(thisframe)
mvocat=pd.concat(frames)
mvocat.reset_index()
#mvocat.columns = mvocat.columns.str.lstrip()
mvocat.columns = mvocat.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
# Out:
# /Users/thompsong/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# write to new CSV file

# %%
mvocat.to_csv('MVOE_CATALOG.csv')

# %%
nrows, ncolumns = mvocat.shape
print(nrows)
# Out:
# 4385595

# %% [markdown]
# Add a quality index to the dataframe

# %%
quality_index = np.zeros(nrows)
mvocat['quality_index'] = quality_index

# %% [markdown]
# Loop over every row of the catalog and change quality factor to 1 if trace is good

# %%
for i in range(nrows):
    #if i % 100==0:
    print(i, end = ' ')
    traceid = mvocat.iloc[i].traceid
    wavfile = mvocat.iloc[i].wavfilepath
    if wavfile.empty:
        continue
    try:
        os.path.exists(wavfile)
    except:
        print(wavfile[40:])
    try:
        if not os.path.exists(wavfile):
            continue
    except:
        continue
    st = obspy.read(wavfile).select(id = traceid)
    if not len(st)==1:
        continue
    data = st[0].data
    if check0andMinus1(data):
        quality_index[i] = 1
    else:
        pass
        #print("There is consecutive 0 or -1. in this recording")
print('Done!')
# Out:
# 0 Series([], Name: 0, dtype: object)
# 1 Series([], Name: 1, dtype: object)
# 2 Series([], Name: 2, dtype: object)
# 3 Series([], Name: 3, dtype: object)
# 4 Series([], Name: 4, dtype: object)
# 5 Series([], Name: 5, dtype: object)
# 6 Series([], Name: 6, dtype: object)
# 7 Series([], Name: 7, dtype: object)
# 8 Series([], Name: 8, dtype: object)
# 9 Series([], Name: 9, dtype: object)
# 10 Series([], Name: 10, dtype: object)
# 11 Series([], Name: 11, dtype: object)
# 12 Series([], Name: 12, dtype: object)
# 13 Series([], Name: 13, dtype: object)
# 14 Series([], Name: 14, dtype: object)
# 15 Series([], Name: 15, dtype: object)
# 16 Series([], Name: 16, dtype: object)
# 17 Series([], Name: 17, dtype: object)
# 18 Series([], Name: 18, dtype: object)
# 19 Series([], Name: 19, dtype: object)
# 20 Series([], Name: 20, dtype: object)
# 21 Series([], Name: 21, dtype: object)
# 22 Series([], Name: 22, dtype: object)
# 23 Series([], Name: 23, dtype: object)
# 24 Series([], Name: 24, dtype: object)
# 25 Series([], Name: 25, dtype: object)
# 26 Series([], Name: 26, dtype: object)
# 27 Series([], Name: 27, dtype: object)
# 28 Series([], Name: 28, dtype: object)
# 29 Series([], Name: 29, dtype: object)
# 30 Series([], Name: 30, dtype: object)
# 31 Series([], Name: 31, dtype: object)
# 32 Series([], Name: 32, dtype: object)
# 33 Series([], Name: 33, dtype: object)
# 34 Series([], Name: 34, dtype: object)
# 35 Series([], Name: 35, dtype: object)
# 36 Series([], Name: 36, dtype: object)
# 37 Series([], Name: 37, dtype: object)
# 38 Series([], Name: 38, dtype: object)
# 39 Series([], Name: 39, dtype: object)
# 40 Series([], Name: 40, dtype: object)
# 41 Series([], Name: 41, dtype: object)
# 42 Series([], Name: 42, dtype: object)
# 43 Series([], Name: 43, dtype: object)
# 44 Series([], Name: 44, dtype: object)
# 45 Series([], Name: 45, dtype: object)
# 46 Series([], Name: 46, dtype: object)
# 47 Series([], Name: 47, dtype: object)
# 48 Series([], Name: 48, dtype: object)
# 49 Series([], Name: 49, dtype: object)
# 50 Series([], Name: 50, dtype: object)
# 51 Series([], Name: 51, dtype: object)
# 52 Series([], Name: 52, dtype: object)
# 53 Series([], Name: 53, dtype: object)
# 54 Series([], Name: 54, dtype: object)
# 55 Series([], Name: 55, dtype: object)
# 56 Series([], Name: 56, dtype: object)
# 57 Series([], Name: 57, dtype: object)
# 58 Series([], Name: 58, dtype: object)
# 59 Series([], Name: 59, dtype: object)
# 60 Series([], Name: 60, dtype: object)
# 61 Series([], Name: 61, dtype: object)
# 62 Series([], Name: 62, dtype: object)
# 63 Series([], Name: 63, dtype: object)
# 64 Series([], Name: 64, dtype: object)
# 65 Series([], Name: 65, dtype: object)
# 66 Series([], Name: 66, dtype: object)
# 67 Series([], Name: 67, dtype: object)
# 68 Series([], Name: 68, dtype: object)
# 69 Series([], Name: 69, dtype: object)
# 70 Series([], Name: 70, dtype: object)
# 71 Series([], Name: 71, dtype: object)
# 72 Series([], Name: 72, dtype: object)
# 73 Series([], Name: 73, dtype: object)
# 74 Series([], Name: 74, dtype: object)
# 75 Series([], Name: 75, dtype: object)
# 76 Series([], Name: 76, dtype: object)
# 77 Series([], Name: 77, dtype: object)
# 78 Series([], Name: 78, dtype: object)
# 79 Series([], Name: 79, dtype: object)
# 80 Series([], Name: 80, dtype: object)
# 81 Series([], Name: 81, dtype: object)
# 82 Series([], Name: 82, dtype: object)
# 83 Series([], Name: 83, dtype: object)
# 84 Series([], Name: 84, dtype: object)
# 85 Series([], Name: 85, dtype: object)
# 86 Series([], Name: 86, dtype: object)
# 87 Series([], Name: 87, dtype: object)
# 88 Series([], Name: 88, dtype: object)
# 89 Series([], Name: 89, dtype: object)
# 90 Series([], Name: 90, dtype: object)
# 91 Series([], Name: 91, dtype: object)
# 92 Series([], Name: 92, dtype: object)
# 93 Series([], Name: 93, dtype: object)
# 94 Series([], Name: 94, dtype: object)
# 95 Series([], Name: 95, dtype: object)
# 96 Series([], Name: 96, dtype: object)
# 97 Series([], Name: 97, dtype: object)
# 98 Series([], Name: 98, dtype: object)
# 99 Series([], Name: 99, dtype: object)
# 100 Series([], Name: 100, dtype: object)
# 101 Series([], Name: 101, dtype: object)
# 102 Series([], Name: 102, dtype: object)
# 103 Series([], Name: 103, dtype: object)
# 104 Series([], Name: 104, dtype: object)
# 105 Series([], Name: 105, dtype: object)
# 106 Series([], Name: 106, dtype: object)
# 107 Series([], Name: 107, dtype: object)
# 108 Series([], Name: 108, dtype: object)
# 109 Series([], Name: 109, dtype: object)
# 110 Series([], Name: 110, dtype: object)
# 111 Series([], Name: 111, dtype: object)
# 112 Series([], Name: 112, dtype: object)
# 113 Series([], Name: 113, dtype: object)
# 114 Series([], Name: 114, dtype: object)
# 115 Series([], Name: 115, dtype: object)
# 116 Series([], Name: 116, dtype: object)
# 117 Series([], Name: 117, dtype: object)
# 118 Series([], Name: 118, dtype: object)
# 119 Series([], Name: 119, dtype: object)
# 120 Series([], Name: 120, dtype: object)
# 121 Series([], Name: 121, dtype: object)
# 122 Series([], Name: 122, dtype: object)
# 123 Series([], Name: 123, dtype: object)
# 124 Series([], Name: 124, dtype: object)
# 125 Series([], Name: 125, dtype: object)
# 126 Series([], Name: 126, dtype: object)
# 127 Series([], Name: 127, dtype: object)
# 128 Series([], Name: 128, dtype: object)
# 129 Series([], Name: 129, dtype: object)
# 130 Series([], Name: 130, dtype: object)
# 131 Series([], Name: 131, dtype: object)
# 132 Series([], Name: 132, dtype: object)
# 133 Series([], Name: 133, dtype: object)
# 134 Series([], Name: 134, dtype: object)
# 135 Series([], Name: 135, dtype: object)
# 136 Series([], Name: 136, dtype: object)
# 137 Series([], Name: 137, dtype: object)
# 138 Series([], Name: 138, dtype: object)
# 139 Series([], Name: 139, dtype: object)
# 140 Series([], Name: 140, dtype: object)
# 141 Series([], Name: 141, dtype: object)
# 142 Series([], Name: 142, dtype: object)
# 143 Series([], Name: 143, dtype: object)
# 144 Series([], Name: 144, dtype: object)
# 145 Series([], Name: 145, dtype: object)
# 146 Series([], Name: 146, dtype: object)
# 147 Series([], Name: 147, dtype: object)
# 148 Series([], Name: 148, dtype: object)
# 149 Series([], Name: 149, dtype: object)
# 150 Series([], Name: 150, dtype: object)
# 151 Series([], Name: 151, dtype: object)
# 152 Series([], Name: 152, dtype: object)
# 153 Series([], Name: 153, dtype: object)
# 154 Series([], Name: 154, dtype: object)
# 155 Series([], Name: 155, dtype: object)
# 156 Series([], Name: 156, dtype: object)
# 157 Series([], Name: 157, dtype: object)
# 158 Series([], Name: 158, dtype: object)
# 159 Series([], Name: 159, dtype: object)
# 160 Series([], Name: 160, dtype: object)
# 161 Series([], Name: 161, dtype: object)
# 162 Series([], Name: 162, dtype: object)
# 163 Series([], Name: 163, dtype: object)
# 164 Series([], Name: 164, dtype: object)
# 165 Series([], Name: 165, dtype: object)
# 166 Series([], Name: 166, dtype: object)
# 167 Series([], Name: 167, dtype: object)
# 168 Series([], Name: 168, dtype: object)
# 169 Series([], Name: 169, dtype: object)
# 170 Series([], Name: 170, dtype: object)
# 171 Series([], Name: 171, dtype: object)
# 172 Series([], Name: 172, dtype: object)
# 173 Series([], Name: 173, dtype: object)
# 174 Series([], Name: 174, dtype: object)
# 175 Series([], Name: 175, dtype: object)
# 176 Series([], Name: 176, dtype: object)
# 177 Series([], Name: 177, dtype: object)
# 178 Series([], Name: 178, dtype: object)
# 179 Series([], Name: 179, dtype: object)
# 180 Series([], Name: 180, dtype: object)
# 181 Series([], Name: 181, dtype: object)
# 182 Series([], Name: 182, dtype: object)
# 183 Series([], Name: 183, dtype: object)
# 184 Series([], Name: 184, dtype: object)
# 185 Series([], Name: 185, dtype: object)
# 186 Series([], Name: 186, dtype: object)
# 187 Series([], Name: 187, dtype: object)
# 188 Series([], Name: 188, dtype: object)
# 189 Series([], Name: 189, dtype: object)
# 190 Series([], Name: 190, dtype: object)
# 191 Series([], Name: 191, dtype: object)
# 192 Series([], Name: 192, dtype: object)
# 193 Series([], Name: 193, dtype: object)
# 194 Series([], Name: 194, dtype: object)
# 195 Series([], Name: 195, dtype: object)
# 196 Series([], Name: 196, dtype: object)
# 197 Series([], Name: 197, dtype: object)
# 198 Series([], Name: 198, dtype: object)
# 199 Series([], Name: 199, dtype: object)
# 200 Series([], Name: 200, dtype: object)
# 201 Series([], Name: 201, dtype: object)
# 202 Series([], Name: 202, dtype: object)
# 203 Series([], Name: 203, dtype: object)
# 204 Series([], Name: 204, dtype: object)
# 205 Series([], Name: 205, dtype: object)
# 206 Series([], Name: 206, dtype: object)
# 207 Series([], Name: 207, dtype: object)
# 208 Series([], Name: 208, dtype: object)
# 209 Series([], Name: 209, dtype: object)
# 210 Series([], Name: 210, dtype: object)
# 211 Series([], Name: 211, dtype: object)
# 212 Series([], Name: 212, dtype: object)
# 213 Series([], Name: 213, dtype: object)
# 214 Series([], Name: 214, dtype: object)
# 215 Series([], Name: 215, dtype: object)
# 216 Series([], Name: 216, dtype: object)
# 217 Series([], Name: 217, dtype: object)
# 218 Series([], Name: 218, dtype: object)
# 219 Series([], Name: 219, dtype: object)
# 220 Series([], Name: 220, dtype: object)
# 221 Series([], Name: 221, dtype: object)
# 222 Series([], Name: 222, dtype: object)
# 223 Series([], Name: 223, dtype: object)
# 224 Series([], Name: 224, dtype: object)
# 225 Series([], Name: 225, dtype: object)
# 226 Series([], Name: 226, dtype: object)
# 227 Series([], Name: 227, dtype: object)
# 228 Series([], Name: 228, dtype: object)
# 229 Series([], Name: 229, dtype: object)
# 230 Series([], Name: 230, dtype: object)
# 231 Series([], Name: 231, dtype: object)
# 232 Series([], Name: 232, dtype: object)
# 233 Series([], Name: 233, dtype: object)
# 234 Series([], Name: 234, dtype: object)
# 235 Series([], Name: 235, dtype: object)
# 236 Series([], Name: 236, dtype: object)
# 237 Series([], Name: 237, dtype: object)
# 238 Series([], Name: 238, dtype: object)
# 239 Series([], Name: 239, dtype: object)
# 240 Series([], Name: 240, dtype: object)
# 241 Series([], Name: 241, dtype: object)
# 242 Series([], Name: 242, dtype: object)
# 243 Series([], Name: 243, dtype: object)
# 244 Series([], Name: 244, dtype: object)
# 245 Series([], Name: 245, dtype: object)
# 246 Series([], Name: 246, dtype: object)
# 247 Series([], Name: 247, dtype: object)
# 248 Series([], Name: 248, dtype: object)
# 249 Series([], Name: 249, dtype: object)
# 250 Series([], Name: 250, dtype: object)
# 251 Series([], Name: 251, dtype: object)
# 252 Series([], Name: 252, dtype: object)
# 253 Series([], Name: 253, dtype: object)
# 254 Series([], Name: 254, dtype: object)
# 255 Series([], Name: 255, dtype: object)
# 256 Series([], Name: 256, dtype: object)
# 257 Series([], Name: 257, dtype: object)
# 258 Series([], Name: 258, dtype: object)
# 259 Series([], Name: 259, dtype: object)
# 260 Series([], Name: 260, dtype: object)
# 261 Series([], Name: 261, dtype: object)
# 262 Series([], Name: 262, dtype: object)
# 263 Series([], Name: 263, dtype: object)
# 264 Series([], Name: 264, dtype: object)
# 265 Series([], Name: 265, dtype: object)
# 266 Series([], Name: 266, dtype: object)
# 267 Series([], Name: 267, dtype: object)
# 268 Series([], Name: 268, dtype: object)
# 269 Series([], Name: 269, dtype: object)
# 270 Series([], Name: 270, dtype: object)
# 271 Series([], Name: 271, dtype: object)
# 272 Series([], Name: 272, dtype: object)
# 273 Series([], Name: 273, dtype: object)
# 274 Series([], Name: 274, dtype: object)
# 275 Series([], Name: 275, dtype: object)
# 276 Series([], Name: 276, dtype: object)
# 277 Series([], Name: 277, dtype: object)
# 278 Series([], Name: 278, dtype: object)
# 279 Series([], Name: 279, dtype: object)
# 280 Series([], Name: 280, dtype: object)
# 281 Series([], Name: 281, dtype: object)
# 282 Series([], Name: 282, dtype: object)
# 283 Series([], Name: 283, dtype: object)
# 284 Series([], Name: 284, dtype: object)
# 285 Series([], Name: 285, dtype: object)
# 286 Series([], Name: 286, dtype: object)
# 287 Series([], Name: 287, dtype: object)
# 288 Series([], Name: 288, dtype: object)
# 289 Series([], Name: 289, dtype: object)
# 290 Series([], Name: 290, dtype: object)
# 291 Series([], Name: 291, dtype: object)
# 292 Series([], Name: 292, dtype: object)
# 293 Series([], Name: 293, dtype: object)
# 294 Series([], Name: 294, dtype: object)
# 295 Series([], Name: 295, dtype: object)
# 296 Series([], Name: 296, dtype: object)
# 297 Series([], Name: 297, dtype: object)
# 298 Series([], Name: 298, dtype: object)
# 299 Series([], Name: 299, dtype: object)
# 300 Series([], Name: 300, dtype: object)
# 301 Series([], Name: 301, dtype: object)
# 302 Series([], Name: 302, dtype: object)
# 303 Series([], Name: 303, dtype: object)
# 304 Series([], Name: 304, dtype: object)
# 305 Series([], Name: 305, dtype: object)
# 306 Series([], Name: 306, dtype: object)
# 307 Series([], Name: 307, dtype: object)
# 308 Series([], Name: 308, dtype: object)
# 309 Series([], Name: 309, dtype: object)
# 310 Series([], Name: 310, dtype: object)
# 311 Series([], Name: 311, dtype: object)
# 312 Series([], Name: 312, dtype: object)
# 313 Series([], Name: 313, dtype: object)
# 314 Series([], Name: 314, dtype: object)
# 315 Series([], Name: 315, dtype: object)
# 316 Series([], Name: 316, dtype: object)
# 317 Series([], Name: 317, dtype: object)
# 318 Series([], Name: 318, dtype: object)
# 319 Series([], Name: 319, dtype: object)
# 320 Series([], Name: 320, dtype: object)
# 321 Series([], Name: 321, dtype: object)
# 322 Series([], Name: 322, dtype: object)
# 323 Series([], Name: 323, dtype: object)
# 324 Series([], Name: 324, dtype: object)
# 325 Series([], Name: 325, dtype: object)
# 326 Series([], Name: 326, dtype: object)
# 327 Series([], Name: 327, dtype: object)
# 328 Series([], Name: 328, dtype: object)
# 329 Series([], Name: 329, dtype: object)
# 330 Series([], Name: 330, dtype: object)
# 331 Series([], Name: 331, dtype: object)
# 332 Series([], Name: 332, dtype: object)
# 333 Series([], Name: 333, dtype: object)
# 334 Series([], Name: 334, dtype: object)
# 335 Series([], Name: 335, dtype: object)
# 336 Series([], Name: 336, dtype: object)
# 337 Series([], Name: 337, dtype: object)
# 338 Series([], Name: 338, dtype: object)
# 339 Series([], Name: 339, dtype: object)
# 340 Series([], Name: 340, dtype: object)
# 341 Series([], Name: 341, dtype: object)
# 342 Series([], Name: 342, dtype: object)
# 343 Series([], Name: 343, dtype: object)
# 344 Series([], Name: 344, dtype: object)
# 345 Series([], Name: 345, dtype: object)
# 346 Series([], Name: 346, dtype: object)
# 347 Series([], Name: 347, dtype: object)
# 348 Series([], Name: 348, dtype: object)
# 349 Series([], Name: 349, dtype: object)
# 350 Series([], Name: 350, dtype: object)
# 351 Series([], Name: 351, dtype: object)
# 352 Series([], Name: 352, dtype: object)
# 353 Series([], Name: 353, dtype: object)
# 354 Series([], Name: 354, dtype: object)
# 355 Series([], Name: 355, dtype: object)
# 356 Series([], Name: 356, dtype: object)
# 357 Series([], Name: 357, dtype: object)
# 358 Series([], Name: 358, dtype: object)
# 359 Series([], Name: 359, dtype: object)
# 360 Series([], Name: 360, dtype: object)
# 361 Series([], Name: 361, dtype: object)
# 362 Series([], Name: 362, dtype: object)
# 363 Series([], Name: 363, dtype: object)
# 364 Series([], Name: 364, dtype: object)
# 365 Series([], Name: 365, dtype: object)
# 366 Series([], Name: 366, dtype: object)
# 367 Series([], Name: 367, dtype: object)
# 368 Series([], Name: 368, dtype: object)
# 369 Series([], Name: 369, dtype: object)
# 370 Series([], Name: 370, dtype: object)
# 371 Series([], Name: 371, dtype: object)
# 372 Series([], Name: 372, dtype: object)
# 373 Series([], Name: 373, dtype: object)
# 374 Series([], Name: 374, dtype: object)
# 375 Series([], Name: 375, dtype: object)
# 376 Series([], Name: 376, dtype: object)
# 377 Series([], Name: 377, dtype: object)
# 378 Series([], Name: 378, dtype: object)
# 379 Series([], Name: 379, dtype: object)
# 380 Series([], Name: 380, dtype: object)
# 381 Series([], Name: 381, dtype: object)
# 382 Series([], Name: 382, dtype: object)
# 383 Series([], Name: 383, dtype: object)
# 384 Series([], Name: 384, dtype: object)
# 385 Series([], Name: 385, dtype: object)
# 386 Series([], Name: 386, dtype: object)
# 387 Series([], Name: 387, dtype: object)
# 388 Series([], Name: 388, dtype: object)
# 389 Series([], Name: 389, dtype: object)
# 390 Series([], Name: 390, dtype: object)
# 391 Series([], Name: 391, dtype: object)
# 392 Series([], Name: 392, dtype: object)
# 393 Series([], Name: 393, dtype: object)
# 394 Series([], Name: 394, dtype: object)
# 395 Series([], Name: 395, dtype: object)
# 396 Series([], Name: 396, dtype: object)
# 397 Series([], Name: 397, dtype: object)
# 398 Series([], Name: 398, dtype: object)
# 399 Series([], Name: 399, dtype: object)
# 400 Series([], Name: 400, dtype: object)
# 401 Series([], Name: 401, dtype: object)
# 402 Series([], Name: 402, dtype: object)
# 403 Series([], Name: 403, dtype: object)
# 404 Series([], Name: 404, dtype: object)
# 405 Series([], Name: 405, dtype: object)
# 406 Series([], Name: 406, dtype: object)
# 407 Series([], Name: 407, dtype: object)
# 408 Series([], Name: 408, dtype: object)
# 409 Series([], Name: 409, dtype: object)
# 410 Series([], Name: 410, dtype: object)
# 411 Series([], Name: 411, dtype: object)
# 412 Series([], Name: 412, dtype: object)
# 413 Series([], Name: 413, dtype: object)
# 414 Series([], Name: 414, dtype: object)
# 415 Series([], Name: 415, dtype: object)
# 416 Series([], Name: 416, dtype: object)
# 417 Series([], Name: 417, dtype: object)
# 418 Series([], Name: 418, dtype: object)
# 419 Series([], Name: 419, dtype: object)
# 420 Series([], Name: 420, dtype: object)
# 421 Series([], Name: 421, dtype: object)
# 422 Series([], Name: 422, dtype: object)
# 423 Series([], Name: 423, dtype: object)
# 424 Series([], Name: 424, dtype: object)
# 425 Series([], Name: 425, dtype: object)
# 426 Series([], Name: 426, dtype: object)
# 427 Series([], Name: 427, dtype: object)
# 428 Series([], Name: 428, dtype: object)
# 429 Series([], Name: 429, dtype: object)
# 430 Series([], Name: 430, dtype: object)
# 431 Series([], Name: 431, dtype: object)
# 432 Series([], Name: 432, dtype: object)
# 433 Series([], Name: 433, dtype: object)
# 434 Series([], Name: 434, dtype: object)
# 435 Series([], Name: 435, dtype: object)
# 436 Series([], Name: 436, dtype: object)
# 437 Series([], Name: 437, dtype: object)
# 438 Series([], Name: 438, dtype: object)
# 439 Series([], Name: 439, dtype: object)
# 440 Series([], Name: 440, dtype: object)
# 441 Series([], Name: 441, dtype: object)
# 442 Series([], Name: 442, dtype: object)
# 443 Series([], Name: 443, dtype: object)
# 444 Series([], Name: 444, dtype: object)
# 445 Series([], Name: 445, dtype: object)
# 446 Series([], Name: 446, dtype: object)
# 447 Series([], Name: 447, dtype: object)
# 448 Series([], Name: 448, dtype: object)
# 449 Series([], Name: 449, dtype: object)
# 450 Series([], Name: 450, dtype: object)
# 451 Series([], Name: 451, dtype: object)
# 452 Series([], Name: 452, dtype: object)
# 453 Series([], Name: 453, dtype: object)
# 454 Series([], Name: 454, dtype: object)
# 455 Series([], Name: 455, dtype: object)
# 456 Series([], Name: 456, dtype: object)
# 457 Series([], Name: 457, dtype: object)
# 458 Series([], Name: 458, dtype: object)
# 459 Series([], Name: 459, dtype: object)
# 460 Series([], Name: 460, dtype: object)
# 461 Series([], Name: 461, dtype: object)
# 462 Series([], Name: 462, dtype: object)
# 463 Series([], Name: 463, dtype: object)
# 464 Series([], Name: 464, dtype: object)
# 465 Series([], Name: 465, dtype: object)
# 466 Series([], Name: 466, dtype: object)
# 467 Series([], Name: 467, dtype: object)
# 468 Series([], Name: 468, dtype: object)
# 469 Series([], Name: 469, dtype: object)
# 470 Series([], Name: 470, dtype: object)
# 471 Series([], Name: 471, dtype: object)
# 472 Series([], Name: 472, dtype: object)
# 473 Series([], Name: 473, dtype: object)
# 474 Series([], Name: 474, dtype: object)
# 475 Series([], Name: 475, dtype: object)
# 476 Series([], Name: 476, dtype: object)
# 477 Series([], Name: 477, dtype: object)
# 478 Series([], Name: 478, dtype: object)
# 479 Series([], Name: 479, dtype: object)
# 480 Series([], Name: 480, dtype: object)
# 481 Series([], Name: 481, dtype: object)
# 482 Series([], Name: 482, dtype: object)
# 483 Series([], Name: 483, dtype: object)
# 484 Series([], Name: 484, dtype: object)
# 485 Series([], Name: 485, dtype: object)
# 486 Series([], Name: 486, dtype: object)
# 487 Series([], Name: 487, dtype: object)
# 488 Series([], Name: 488, dtype: object)
# 489 Series([], Name: 489, dtype: object)
# 490 Series([], Name: 490, dtype: object)
# 491 Series([], Name: 491, dtype: object)
# 492 Series([], Name: 492, dtype: object)
# 493 Series([], Name: 493, dtype: object)
# 494 Series([], Name: 494, dtype: object)
# 495 Series([], Name: 495, dtype: object)
# 496 Series([], Name: 496, dtype: object)
# 497 Series([], Name: 497, dtype: object)
# 498 Series([], Name: 498, dtype: object)
# 499 Series([], Name: 499, dtype: object)
# 500 Series([], Name: 500, dtype: object)
# 501 Series([], Name: 501, dtype: object)
# 502 Series([], Name: 502, dtype: object)
# 503 Series([], Name: 503, dtype: object)
# 504 Series([], Name: 504, dtype: object)
# 505 Series([], Name: 505, dtype: object)
# 506 Series([], Name: 506, dtype: object)
# 507 Series([], Name: 507, dtype: object)
# 508 Series([], Name: 508, dtype: object)
# 509 Series([], Name: 509, dtype: object)
# 510 Series([], Name: 510, dtype: object)
# 511 Series([], Name: 511, dtype: object)
# 512 Series([], Name: 512, dtype: object)
# 513 Series([], Name: 513, dtype: object)
# 514 Series([], Name: 514, dtype: object)
# 515 Series([], Name: 515, dtype: object)
# 516 Series([], Name: 516, dtype: object)
# 517 Series([], Name: 517, dtype: object)
# 518 Series([], Name: 518, dtype: object)
# 519 Series([], Name: 519, dtype: object)
# 520 Series([], Name: 520, dtype: object)
# 521 Series([], Name: 521, dtype: object)
# 522 Series([], Name: 522, dtype: object)
# 523 Series([], Name: 523, dtype: object)
# 524 Series([], Name: 524, dtype: object)
# 525 Series([], Name: 525, dtype: object)
# 526 Series([], Name: 526, dtype: object)
# 527 Series([], Name: 527, dtype: object)
# 528 Series([], Name: 528, dtype: object)
# 529 Series([], Name: 529, dtype: object)
# 530 Series([], Name: 530, dtype: object)
# 531 Series([], Name: 531, dtype: object)
# 532 Series([], Name: 532, dtype: object)
# 533 Series([], Name: 533, dtype: object)
# 534 Series([], Name: 534, dtype: object)
# 535 Series([], Name: 535, dtype: object)
# 536 Series([], Name: 536, dtype: object)
# 537 Series([], Name: 537, dtype: object)
# 538 Series([], Name: 538, dtype: object)
# 539 Series([], Name: 539, dtype: object)
# 540 Series([], Name: 540, dtype: object)
# 541 Series([], Name: 541, dtype: object)
# 542 Series([], Name: 542, dtype: object)
# 543 Series([], Name: 543, dtype: object)
# 544 Series([], Name: 544, dtype: object)
# 545 Series([], Name: 545, dtype: object)
# 546 Series([], Name: 546, dtype: object)
# 547 Series([], Name: 547, dtype: object)
# 548 Series([], Name: 548, dtype: object)
# 549 Series([], Name: 549, dtype: object)
# 550 Series([], Name: 550, dtype: object)
# 551 Series([], Name: 551, dtype: object)
# 552 Series([], Name: 552, dtype: object)
# 553 Series([], Name: 553, dtype: object)
# 554 Series([], Name: 554, dtype: object)
# 555 Series([], Name: 555, dtype: object)
# 556 Series([], Name: 556, dtype: object)
# 557 Series([], Name: 557, dtype: object)
# 558 Series([], Name: 558, dtype: object)
# 559 Series([], Name: 559, dtype: object)
# 560 Series([], Name: 560, dtype: object)
# 561 Series([], Name: 561, dtype: object)
# 562 Series([], Name: 562, dtype: object)
# 563 Series([], Name: 563, dtype: object)
# 564 Series([], Name: 564, dtype: object)
# 565 Series([], Name: 565, dtype: object)
# 566 Series([], Name: 566, dtype: object)
# 567 Series([], Name: 567, dtype: object)
# 568 Series([], Name: 568, dtype: object)
# 569 Series([], Name: 569, dtype: object)
# 570 Series([], Name: 570, dtype: object)
# 571 Series([], Name: 571, dtype: object)
# 572 Series([], Name: 572, dtype: object)
# 573 Series([], Name: 573, dtype: object)
# 574 Series([], Name: 574, dtype: object)
# 575 Series([], Name: 575, dtype: object)
# 576 Series([], Name: 576, dtype: object)
# 577 Series([], Name: 577, dtype: object)
# 578 Series([], Name: 578, dtype: object)
# 579 Series([], Name: 579, dtype: object)
# 580 Series([], Name: 580, dtype: object)
# 581 Series([], Name: 581, dtype: object)
# 582 Series([], Name: 582, dtype: object)
# 583 Series([], Name: 583, dtype: object)
# 584 Series([], Name: 584, dtype: object)
# 585 Series([], Name: 585, dtype: object)
# 586 Series([], Name: 586, dtype: object)
# 587 Series([], Name: 587, dtype: object)
# 588 Series([], Name: 588, dtype: object)
# 589 Series([], Name: 589, dtype: object)
# 590 Series([], Name: 590, dtype: object)
# 591 Series([], Name: 591, dtype: object)
# 592 Series([], Name: 592, dtype: object)
# 593 Series([], Name: 593, dtype: object)
# 594 Series([], Name: 594, dtype: object)
# 595 Series([], Name: 595, dtype: object)
# 596 Series([], Name: 596, dtype: object)
# 597 Series([], Name: 597, dtype: object)
# 598 Series([], Name: 598, dtype: object)
# 599 Series([], Name: 599, dtype: object)
# 600 Series([], Name: 600, dtype: object)
# 601 Series([], Name: 601, dtype: object)
# 602 Series([], Name: 602, dtype: object)
# 603 Series([], Name: 603, dtype: object)
# 604 Series([], Name: 604, dtype: object)
# 605 Series([], Name: 605, dtype: object)
# 606 Series([], Name: 606, dtype: object)
# 607 Series([], Name: 607, dtype: object)
# 608 Series([], Name: 608, dtype: object)
# 609 Series([], Name: 609, dtype: object)
# 610 Series([], Name: 610, dtype: object)
# 611 Series([], Name: 611, dtype: object)
# 612 Series([], Name: 612, dtype: object)
# 613 Series([], Name: 613, dtype: object)
# 614 Series([], Name: 614, dtype: object)
# 615 Series([], Name: 615, dtype: object)
# 616 Series([], Name: 616, dtype: object)
# 617 Series([], Name: 617, dtype: object)
# 618 Series([], Name: 618, dtype: object)
# 619 Series([], Name: 619, dtype: object)
# 620 Series([], Name: 620, dtype: object)
# 621 Series([], Name: 621, dtype: object)
# 622 Series([], Name: 622, dtype: object)
# 623 Series([], Name: 623, dtype: object)
# 624 Series([], Name: 624, dtype: object)
# 625 Series([], Name: 625, dtype: object)
# 626 Series([], Name: 626, dtype: object)
# 627 Series([], Name: 627, dtype: object)
# 628 Series([], Name: 628, dtype: object)
# 629 Series([], Name: 629, dtype: object)
# 630 Series([], Name: 630, dtype: object)
# 631 Series([], Name: 631, dtype: object)
# 632 Series([], Name: 632, dtype: object)
# 633 Series([], Name: 633, dtype: object)
# 634 Series([], Name: 634, dtype: object)
# 635 Series([], Name: 635, dtype: object)
# 636 Series([], Name: 636, dtype: object)
# 637 Series([], Name: 637, dtype: object)
# 638 Series([], Name: 638, dtype: object)
# 639 Series([], Name: 639, dtype: object)
# 640 Series([], Name: 640, dtype: object)
# 641 Series([], Name: 641, dtype: object)
# 642 Series([], Name: 642, dtype: object)
# 643 Series([], Name: 643, dtype: object)
# 644 Series([], Name: 644, dtype: object)
# 645 Series([], Name: 645, dtype: object)
# 646 Series([], Name: 646, dtype: object)
# 647 Series([], Name: 647, dtype: object)
# 648 Series([], Name: 648, dtype: object)
# 649 Series([], Name: 649, dtype: object)
# 650 Series([], Name: 650, dtype: object)
# 651 Series([], Name: 651, dtype: object)
# 652 Series([], Name: 652, dtype: object)
# 653 Series([], Name: 653, dtype: object)
# 654 Series([], Name: 654, dtype: object)
# 655 Series([], Name: 655, dtype: object)
# 656 Series([], Name: 656, dtype: object)
# 657 Series([], Name: 657, dtype: object)
# 658 Series([], Name: 658, dtype: object)
# 659 Series([], Name: 659, dtype: object)
# 660 Series([], Name: 660, dtype: object)
# 661 Series([], Name: 661, dtype: object)
# 662 Series([], Name: 662, dtype: object)
# 663 Series([], Name: 663, dtype: object)
# 664 Series([], Name: 664, dtype: object)
# 665 Series([], Name: 665, dtype: object)
# 666 Series([], Name: 666, dtype: object)
# 667 Series([], Name: 667, dtype: object)
# 668 Series([], Name: 668, dtype: object)
# 669 Series([], Name: 669, dtype: object)
# 670 Series([], Name: 670, dtype: object)
# 671 Series([], Name: 671, dtype: object)
# 672 Series([], Name: 672, dtype: object)
# 673 Series([], Name: 673, dtype: object)
# 674 Series([], Name: 674, dtype: object)
# 675 Series([], Name: 675, dtype: object)
# 676 Series([], Name: 676, dtype: object)
# 677 Series([], Name: 677, dtype: object)
# 678 Series([], Name: 678, dtype: object)
# 679 Series([], Name: 679, dtype: object)
# 680 Series([], Name: 680, dtype: object)
# 681 Series([], Name: 681, dtype: object)
# 682 Series([], Name: 682, dtype: object)
# 683 Series([], Name: 683, dtype: object)
# 684 Series([], Name: 684, dtype: object)
# 685 Series([], Name: 685, dtype: object)
# 686 Series([], Name: 686, dtype: object)
# 687 Series([], Name: 687, dtype: object)
# 688 Series([], Name: 688, dtype: object)
# 689 Series([], Name: 689, dtype: object)
# 690 Series([], Name: 690, dtype: object)
# 691 Series([], Name: 691, dtype: object)
# 692 Series([], Name: 692, dtype: object)
# 693 Series([], Name: 693, dtype: object)
# 694 Series([], Name: 694, dtype: object)
# 695 Series([], Name: 695, dtype: object)
# 696 Series([], Name: 696, dtype: object)
# 697 Series([], Name: 697, dtype: object)
# 698 Series([], Name: 698, dtype: object)
# 699 Series([], Name: 699, dtype: object)
# 700 Series([], Name: 700, dtype: object)
# 701 Series([], Name: 701, dtype: object)
# 702 Series([], Name: 702, dtype: object)
# 703 Series([], Name: 703, dtype: object)
# 704 Series([], Name: 704, dtype: object)
# 705 Series([], Name: 705, dtype: object)
# 706 Series([], Name: 706, dtype: object)
# 707 Series([], Name: 707, dtype: object)
# 708 Series([], Name: 708, dtype: object)
# 709 Series([], Name: 709, dtype: object)
# 710 Series([], Name: 710, dtype: object)
# 711 Series([], Name: 711, dtype: object)
# 712 Series([], Name: 712, dtype: object)
# 713 Series([], Name: 713, dtype: object)
# 714 Series([], Name: 714, dtype: object)
# 715 Series([], Name: 715, dtype: object)
# 716 Series([], Name: 716, dtype: object)
# 717 Series([], Name: 717, dtype: object)
# 718 Series([], Name: 718, dtype: object)
# 719 Series([], Name: 719, dtype: object)
# 720 Series([], Name: 720, dtype: object)
# 721 Series([], Name: 721, dtype: object)
# 722 Series([], Name: 722, dtype: object)
# 723 Series([], Name: 723, dtype: object)
# 724 Series([], Name: 724, dtype: object)
# 725 Series([], Name: 725, dtype: object)
# 726 Series([], Name: 726, dtype: object)
# 727 Series([], Name: 727, dtype: object)
# 728 Series([], Name: 728, dtype: object)
# 729 Series([], Name: 729, dtype: object)
# 730 Series([], Name: 730, dtype: object)
# 731 Series([], Name: 731, dtype: object)
# 732 Series([], Name: 732, dtype: object)
# 733 Series([], Name: 733, dtype: object)
# 734 Series([], Name: 734, dtype: object)
# 735 Series([], Name: 735, dtype: object)
# 736 Series([], Name: 736, dtype: object)
# 737 Series([], Name: 737, dtype: object)
# 738 Series([], Name: 738, dtype: object)
# 739 Series([], Name: 739, dtype: object)
# 740 Series([], Name: 740, dtype: object)
# 741 Series([], Name: 741, dtype: object)
# 742 Series([], Name: 742, dtype: object)
# 743 Series([], Name: 743, dtype: object)
# 744 Series([], Name: 744, dtype: object)
# 745 Series([], Name: 745, dtype: object)
# 746 Series([], Name: 746, dtype: object)
# 747 Series([], Name: 747, dtype: object)
# 748 Series([], Name: 748, dtype: object)
# 749 Series([], Name: 749, dtype: object)
# 750 Series([], Name: 750, dtype: object)
# 751 Series([], Name: 751, dtype: object)
# 752 Series([], Name: 752, dtype: object)
# 753 Series([], Name: 753, dtype: object)
# 754 Series([], Name: 754, dtype: object)
# 755 Series([], Name: 755, dtype: object)
# 756 Series([], Name: 756, dtype: object)
# 757 Series([], Name: 757, dtype: object)
# 758 Series([], Name: 758, dtype: object)
# 759 Series([], Name: 759, dtype: object)
# 760 Series([], Name: 760, dtype: object)
# 761 Series([], Name: 761, dtype: object)
# 762 Series([], Name: 762, dtype: object)
# 763 Series([], Name: 763, dtype: object)
# 764 Series([], Name: 764, dtype: object)
# 765 Series([], Name: 765, dtype: object)
# 766 Series([], Name: 766, dtype: object)
# 767 Series([], Name: 767, dtype: object)
# 768 Series([], Name: 768, dtype: object)
# 769 Series([], Name: 769, dtype: object)
# 770 Series([], Name: 770, dtype: object)
# 771 Series([], Name: 771, dtype: object)
# 772 Series([], Name: 772, dtype: object)
# 773 Series([], Name: 773, dtype: object)
# 774 Series([], Name: 774, dtype: object)
# 775 Series([], Name: 775, dtype: object)
# 776 Series([], Name: 776, dtype: object)
# 777 Series([], Name: 777, dtype: object)
# 778 Series([], Name: 778, dtype: object)
# 779 Series([], Name: 779, dtype: object)
# 780 Series([], Name: 780, dtype: object)
# 781 Series([], Name: 781, dtype: object)
# 782 Series([], Name: 782, dtype: object)
# 783 Series([], Name: 783, dtype: object)
# 784 Series([], Name: 784, dtype: object)
# 785 Series([], Name: 785, dtype: object)
# 786 Series([], Name: 786, dtype: object)
# 787 Series([], Name: 787, dtype: object)
# 788 Series([], Name: 788, dtype: object)
# 789 Series([], Name: 789, dtype: object)
# 790 Series([], Name: 790, dtype: object)
# 791 Series([], Name: 791, dtype: object)
# 792 Series([], Name: 792, dtype: object)
# 793 Series([], Name: 793, dtype: object)
# 794 Series([], Name: 794, dtype: object)
# 795 Series([], Name: 795, dtype: object)
# 796 Series([], Name: 796, dtype: object)
# 797 Series([], Name: 797, dtype: object)
# 798 Series([], Name: 798, dtype: object)
# 799 Series([], Name: 799, dtype: object)
# 800 Series([], Name: 800, dtype: object)
# 801 Series([], Name: 801, dtype: object)
# 802 Series([], Name: 802, dtype: object)
# 803 Series([], Name: 803, dtype: object)
# 804 Series([], Name: 804, dtype: object)
# 805 Series([], Name: 805, dtype: object)
# 806 Series([], Name: 806, dtype: object)
# 807 Series([], Name: 807, dtype: object)
# 808 Series([], Name: 808, dtype: object)
# 809 Series([], Name: 809, dtype: object)
# 810 Series([], Name: 810, dtype: object)
# 811 Series([], Name: 811, dtype: object)
# 812 Series([], Name: 812, dtype: object)
# 813 Series([], Name: 813, dtype: object)
# 814 Series([], Name: 814, dtype: object)
# 815 Series([], Name: 815, dtype: object)
# 816 Series([], Name: 816, dtype: object)
# 817 Series([], Name: 817, dtype: object)
# 818 Series([], Name: 818, dtype: object)
# 819 Series([], Name: 819, dtype: object)
# 820 Series([], Name: 820, dtype: object)
# 821 Series([], Name: 821, dtype: object)
# 822 Series([], Name: 822, dtype: object)
# 823 Series([], Name: 823, dtype: object)
# 824 Series([], Name: 824, dtype: object)
# 825 Series([], Name: 825, dtype: object)
# 826 Series([], Name: 826, dtype: object)
# 827 Series([], Name: 827, dtype: object)
# 828 Series([], Name: 828, dtype: object)
# 829 Series([], Name: 829, dtype: object)
# 830 Series([], Name: 830, dtype: object)
# 831 Series([], Name: 831, dtype: object)
# 832 Series([], Name: 832, dtype: object)
# 833 Series([], Name: 833, dtype: object)
# 834 Series([], Name: 834, dtype: object)
# 835 Series([], Name: 835, dtype: object)
# 836 Series([], Name: 836, dtype: object)
# 837 Series([], Name: 837, dtype: object)
# 838 Series([], Name: 838, dtype: object)
# 839 Series([], Name: 839, dtype: object)
# 840 Series([], Name: 840, dtype: object)
# 841 Series([], Name: 841, dtype: object)
# 842 Series([], Name: 842, dtype: object)
# 843 Series([], Name: 843, dtype: object)
# 844 Series([], Name: 844, dtype: object)
# 845 Series([], Name: 845, dtype: object)
# 846 Series([], Name: 846, dtype: object)
# 847 Series([], Name: 847, dtype: object)
# 848 Series([], Name: 848, dtype: object)
# 849 Series([], Name: 849, dtype: object)
# 850 Series([], Name: 850, dtype: object)
# 851 Series([], Name: 851, dtype: object)
# 852 Series([], Name: 852, dtype: object)
# 853 Series([], Name: 853, dtype: object)
# 854 Series([], Name: 854, dtype: object)
# 855 Series([], Name: 855, dtype: object)
# 856 Series([], Name: 856, dtype: object)
# 857 Series([], Name: 857, dtype: object)
# 858 Series([], Name: 858, dtype: object)
# 859 Series([], Name: 859, dtype: object)
# 860 Series([], Name: 860, dtype: object)
# 861 Series([], Name: 861, dtype: object)
# 862 Series([], Name: 862, dtype: object)
# 863 Series([], Name: 863, dtype: object)
# 864 Series([], Name: 864, dtype: object)
# 865 Series([], Name: 865, dtype: object)
# 866 Series([], Name: 866, dtype: object)
# 867 Series([], Name: 867, dtype: object)
# 868 Series([], Name: 868, dtype: object)
# 869 Series([], Name: 869, dtype: object)
# 870 Series([], Name: 870, dtype: object)
# 871 Series([], Name: 871, dtype: object)
# 872 Series([], Name: 872, dtype: object)
# 873 Series([], Name: 873, dtype: object)
# 874 Series([], Name: 874, dtype: object)
# 875 Series([], Name: 875, dtype: object)
# 876 Series([], Name: 876, dtype: object)
# 877 Series([], Name: 877, dtype: object)
# 878 Series([], Name: 878, dtype: object)
# 879 Series([], Name: 879, dtype: object)
# 880 Series([], Name: 880, dtype: object)
# 881 Series([], Name: 881, dtype: object)
# 882 Series([], Name: 882, dtype: object)
# 883 Series([], Name: 883, dtype: object)
# 884 Series([], Name: 884, dtype: object)
# 885 Series([], Name: 885, dtype: object)
# 886 Series([], Name: 886, dtype: object)
# 887 Series([], Name: 887, dtype: object)
# 888 Series([], Name: 888, dtype: object)
# 889 Series([], Name: 889, dtype: object)
# 890 Series([], Name: 890, dtype: object)
# 891 Series([], Name: 891, dtype: object)
# 892 Series([], Name: 892, dtype: object)
# 893 Series([], Name: 893, dtype: object)
# 894 Series([], Name: 894, dtype: object)
# 895 Series([], Name: 895, dtype: object)
# 896 Series([], Name: 896, dtype: object)
# 897 Series([], Name: 897, dtype: object)
# 898 Series([], Name: 898, dtype: object)
# 899 Series([], Name: 899, dtype: object)
# 900 Series([], Name: 900, dtype: object)
# 901 Series([], Name: 901, dtype: object)
# 902 Series([], Name: 902, dtype: object)
# 903 Series([], Name: 903, dtype: object)
# 904 Series([], Name: 904, dtype: object)
# 905 Series([], Name: 905, dtype: object)
# 906 Series([], Name: 906, dtype: object)
# 907 Series([], Name: 907, dtype: object)
# 908 Series([], Name: 908, dtype: object)
# 909 Series([], Name: 909, dtype: object)
# 910 Series([], Name: 910, dtype: object)
# 911 Series([], Name: 911, dtype: object)
# 912 Series([], Name: 912, dtype: object)
# 913 Series([], Name: 913, dtype: object)
# 914 Series([], Name: 914, dtype: object)
# 915 Series([], Name: 915, dtype: object)
# 916 Series([], Name: 916, dtype: object)
# 917 Series([], Name: 917, dtype: object)
# 918 Series([], Name: 918, dtype: object)
# 919 Series([], Name: 919, dtype: object)
# 920 Series([], Name: 920, dtype: object)
# 921 Series([], Name: 921, dtype: object)
# 922 Series([], Name: 922, dtype: object)
# 923 Series([], Name: 923, dtype: object)
# 924 Series([], Name: 924, dtype: object)
# 925 Series([], Name: 925, dtype: object)
# 926 Series([], Name: 926, dtype: object)
# 927 Series([], Name: 927, dtype: object)
# 928 Series([], Name: 928, dtype: object)
# 929 Series([], Name: 929, dtype: object)
# 930 Series([], Name: 930, dtype: object)
# 931 Series([], Name: 931, dtype: object)
# 932 Series([], Name: 932, dtype: object)
# 933 Series([], Name: 933, dtype: object)
# 934 Series([], Name: 934, dtype: object)
# 935 Series([], Name: 935, dtype: object)
# 936 Series([], Name: 936, dtype: object)
# 937 Series([], Name: 937, dtype: object)
# 938 Series([], Name: 938, dtype: object)
# 939 Series([], Name: 939, dtype: object)
# 940 Series([], Name: 940, dtype: object)
# 941 Series([], Name: 941, dtype: object)
# 942 Series([], Name: 942, dtype: object)
# 943 Series([], Name: 943, dtype: object)
# 944 Series([], Name: 944, dtype: object)
# 945 Series([], Name: 945, dtype: object)
# 946 Series([], Name: 946, dtype: object)
# 947 Series([], Name: 947, dtype: object)
# 948 Series([], Name: 948, dtype: object)
# 949 Series([], Name: 949, dtype: object)
# 950 Series([], Name: 950, dtype: object)
# 951 Series([], Name: 951, dtype: object)
# 952 Series([], Name: 952, dtype: object)
# 953 Series([], Name: 953, dtype: object)
# 954 Series([], Name: 954, dtype: object)
# 955 Series([], Name: 955, dtype: object)
# 956 Series([], Name: 956, dtype: object)
# 957 Series([], Name: 957, dtype: object)
# 958 Series([], Name: 958, dtype: object)
# 959 Series([], Name: 959, dtype: object)
# 960 Series([], Name: 960, dtype: object)
# 961 Series([], Name: 961, dtype: object)
# 962 Series([], Name: 962, dtype: object)
# 963 Series([], Name: 963, dtype: object)
# 964 Series([], Name: 964, dtype: object)
# 965 Series([], Name: 965, dtype: object)
# 966 Series([], Name: 966, dtype: object)
# 967 Series([], Name: 967, dtype: object)
# 968 Series([], Name: 968, dtype: object)
# 969 Series([], Name: 969, dtype: object)
# 970 Series([], Name: 970, dtype: object)
# 971 Series([], Name: 971, dtype: object)
# 972 Series([], Name: 972, dtype: object)
# 973 Series([], Name: 973, dtype: object)
# 974 Series([], Name: 974, dtype: object)
# 975 Series([], Name: 975, dtype: object)
# 976 Series([], Name: 976, dtype: object)
# 977 Series([], Name: 977, dtype: object)
# 978 Series([], Name: 978, dtype: object)
# 979 Series([], Name: 979, dtype: object)
# 980 Series([], Name: 980, dtype: object)
# 981 Series([], Name: 981, dtype: object)
# 982 Series([], Name: 982, dtype: object)
# 983 Series([], Name: 983, dtype: object)
# 984 Series([], Name: 984, dtype: object)
# 985 Series([], Name: 985, dtype: object)
# 986 Series([], Name: 986, dtype: object)
# 987 Series([], Name: 987, dtype: object)
# 988 Series([], Name: 988, dtype: object)
# 989 Series([], Name: 989, dtype: object)
# 990 Series([], Name: 990, dtype: object)
# 991 Series([], Name: 991, dtype: object)
# 992 Series([], Name: 992, dtype: object)
# 993 Series([], Name: 993, dtype: object)
# 994 Series([], Name: 994, dtype: object)
# 995 Series([], Name: 995, dtype: object)
# 996 Series([], Name: 996, dtype: object)
# 997 Series([], Name: 997, dtype: object)
# 998 Series([], Name: 998, dtype: object)
# 999 Series([], Name: 999, dtype: object)
# 1000 Series([], Name: 1000, dtype: object)
# 1001 Series([], Name: 1001, dtype: object)
# 1002 Series([], Name: 1002, dtype: object)
# 1003 Series([], Name: 1003, dtype: object)
# 1004 Series([], Name: 1004, dtype: object)
# 1005 Series([], Name: 1005, dtype: object)
# 1006 Series([], Name: 1006, dtype: object)
# 1007 Series([], Name: 1007, dtype: object)
# 1008 Series([], Name: 1008, dtype: object)
# 1009 Series([], Name: 1009, dtype: object)
# 1010 Series([], Name: 1010, dtype: object)
# 1011 Series([], Name: 1011, dtype: object)
# 1012 Series([], Name: 1012, dtype: object)
# 1013 Series([], Name: 1013, dtype: object)
# 1014 Series([], Name: 1014, dtype: object)
# 1015 Series([], Name: 1015, dtype: object)
# 1016 Series([], Name: 1016, dtype: object)
# 1017 Series([], Name: 1017, dtype: object)
# 1018 Series([], Name: 1018, dtype: object)
# 1019 Series([], Name: 1019, dtype: object)
# 1020 Series([], Name: 1020, dtype: object)
# 1021 Series([], Name: 1021, dtype: object)
# 1022 Series([], Name: 1022, dtype: object)
# 1023 Series([], Name: 1023, dtype: object)
# 1024 Series([], Name: 1024, dtype: object)
# 1025 Series([], Name: 1025, dtype: object)
# 1026 Series([], Name: 1026, dtype: object)
# 1027 Series([], Name: 1027, dtype: object)
# 1028 Series([], Name: 1028, dtype: object)
# 1029 Series([], Name: 1029, dtype: object)
# 1030 Series([], Name: 1030, dtype: object)
# 1031 Series([], Name: 1031, dtype: object)
# 1032 Series([], Name: 1032, dtype: object)
# 1033 Series([], Name: 1033, dtype: object)
# 1034 Series([], Name: 1034, dtype: object)
# 1035 Series([], Name: 1035, dtype: object)
# 1036 Series([], Name: 1036, dtype: object)
# 1037 Series([], Name: 1037, dtype: object)
# 1038 Series([], Name: 1038, dtype: object)
# 1039 Series([], Name: 1039, dtype: object)
# 1040 Series([], Name: 1040, dtype: object)
# 1041 Series([], Name: 1041, dtype: object)
# 1042 Series([], Name: 1042, dtype: object)
# 1043 Series([], Name: 1043, dtype: object)
# 1044 Series([], Name: 1044, dtype: object)
# 1045 Series([], Name: 1045, dtype: object)
# 1046 Series([], Name: 1046, dtype: object)
# 1047 Series([], Name: 1047, dtype: object)
# 1048 Series([], Name: 1048, dtype: object)
# 1049 Series([], Name: 1049, dtype: object)
# 1050 Series([], Name: 1050, dtype: object)
# 1051 Series([], Name: 1051, dtype: object)
# 1052 Series([], Name: 1052, dtype: object)
# 1053 Series([], Name: 1053, dtype: object)
# 1054 Series([], Name: 1054, dtype: object)
# 1055 Series([], Name: 1055, dtype: object)
# 1056 Series([], Name: 1056, dtype: object)
# 1057 Series([], Name: 1057, dtype: object)
# 1058 Series([], Name: 1058, dtype: object)
# 1059 Series([], Name: 1059, dtype: object)
# 1060 Series([], Name: 1060, dtype: object)
# 1061 Series([], Name: 1061, dtype: object)
# 1062 Series([], Name: 1062, dtype: object)
# 1063 Series([], Name: 1063, dtype: object)
# 1064 Series([], Name: 1064, dtype: object)
# 1065 Series([], Name: 1065, dtype: object)
# 1066 Series([], Name: 1066, dtype: object)
# 1067 Series([], Name: 1067, dtype: object)
# 1068 Series([], Name: 1068, dtype: object)
# 1069 Series([], Name: 1069, dtype: object)
# 1070 Series([], Name: 1070, dtype: object)
# 1071 Series([], Name: 1071, dtype: object)
# 1072 Series([], Name: 1072, dtype: object)
# 1073 Series([], Name: 1073, dtype: object)
# 1074 Series([], Name: 1074, dtype: object)
# 1075 Series([], Name: 1075, dtype: object)
# 1076 Series([], Name: 1076, dtype: object)
# 1077 Series([], Name: 1077, dtype: object)
# 1078 Series([], Name: 1078, dtype: object)
# 1079 Series([], Name: 1079, dtype: object)
# 1080 Series([], Name: 1080, dtype: object)
# 1081 Series([], Name: 1081, dtype: object)
# 1082 Series([], Name: 1082, dtype: object)
# 1083 Series([], Name: 1083, dtype: object)
# 1084 Series([], Name: 1084, dtype: object)
# 1085 Series([], Name: 1085, dtype: object)
# 1086 Series([], Name: 1086, dtype: object)
# 1087 Series([], Name: 1087, dtype: object)
# 1088 Series([], Name: 1088, dtype: object)
# 1089 Series([], Name: 1089, dtype: object)
# 1090 Series([], Name: 1090, dtype: object)
# 1091 Series([], Name: 1091, dtype: object)
# 1092 Series([], Name: 1092, dtype: object)
# 1093 Series([], Name: 1093, dtype: object)
# 1094 Series([], Name: 1094, dtype: object)
# 1095 Series([], Name: 1095, dtype: object)
# 1096 Series([], Name: 1096, dtype: object)
# 1097 Series([], Name: 1097, dtype: object)
# 1098 Series([], Name: 1098, dtype: object)
# 1099 Series([], Name: 1099, dtype: object)
# 1100 Series([], Name: 1100, dtype: object)
# 1101 Series([], Name: 1101, dtype: object)
# 1102 Series([], Name: 1102, dtype: object)
# 1103 Series([], Name: 1103, dtype: object)
# 1104 Series([], Name: 1104, dtype: object)
# 1105 Series([], Name: 1105, dtype: object)
# 1106 Series([], Name: 1106, dtype: object)
# 1107 Series([], Name: 1107, dtype: object)
# 1108 Series([], Name: 1108, dtype: object)
# 1109 Series([], Name: 1109, dtype: object)
# 1110 Series([], Name: 1110, dtype: object)
# 1111 Series([], Name: 1111, dtype: object)
# 1112 Series([], Name: 1112, dtype: object)
# 1113 Series([], Name: 1113, dtype: object)
# 1114 Series([], Name: 1114, dtype: object)
# 1115 Series([], Name: 1115, dtype: object)
# 1116 Series([], Name: 1116, dtype: object)
# 1117 Series([], Name: 1117, dtype: object)
# 1118 Series([], Name: 1118, dtype: object)
# 1119 Series([], Name: 1119, dtype: object)
# 1120 Series([], Name: 1120, dtype: object)
# 1121 Series([], Name: 1121, dtype: object)
# 1122 Series([], Name: 1122, dtype: object)
# 1123 Series([], Name: 1123, dtype: object)
# 1124 Series([], Name: 1124, dtype: object)
# 1125 Series([], Name: 1125, dtype: object)
# 1126 Series([], Name: 1126, dtype: object)
# 1127 Series([], Name: 1127, dtype: object)
# 1128 Series([], Name: 1128, dtype: object)
# 1129 Series([], Name: 1129, dtype: object)
# 1130 Series([], Name: 1130, dtype: object)
# 1131 Series([], Name: 1131, dtype: object)
# 1132 Series([], Name: 1132, dtype: object)
# 1133 Series([], Name: 1133, dtype: object)
# 1134 Series([], Name: 1134, dtype: object)
# 1135 Series([], Name: 1135, dtype: object)
# 1136 Series([], Name: 1136, dtype: object)
# 1137 Series([], Name: 1137, dtype: object)
# 1138 Series([], Name: 1138, dtype: object)
# 1139 Series([], Name: 1139, dtype: object)
# 1140 Series([], Name: 1140, dtype: object)
# 1141 Series([], Name: 1141, dtype: object)
# 1142 Series([], Name: 1142, dtype: object)
# 1143 Series([], Name: 1143, dtype: object)
# 1144 Series([], Name: 1144, dtype: object)
# 1145 Series([], Name: 1145, dtype: object)
# 1146 Series([], Name: 1146, dtype: object)
# 1147 Series([], Name: 1147, dtype: object)
# 1148 Series([], Name: 1148, dtype: object)
# 1149 Series([], Name: 1149, dtype: object)
# 1150 Series([], Name: 1150, dtype: object)
# 1151 Series([], Name: 1151, dtype: object)
# 1152 Series([], Name: 1152, dtype: object)
# 1153 Series([], Name: 1153, dtype: object)
# 1154 Series([], Name: 1154, dtype: object)
# 1155 Series([], Name: 1155, dtype: object)
# 1156 Series([], Name: 1156, dtype: object)
# 1157 Series([], Name: 1157, dtype: object)
# 1158 Series([], Name: 1158, dtype: object)
# 1159 Series([], Name: 1159, dtype: object)
# 1160 Series([], Name: 1160, dtype: object)
# 1161 Series([], Name: 1161, dtype: object)
# 1162 Series([], Name: 1162, dtype: object)
# 1163 Series([], Name: 1163, dtype: object)
# 1164 Series([], Name: 1164, dtype: object)
# 1165 Series([], Name: 1165, dtype: object)
# 1166 Series([], Name: 1166, dtype: object)
# ...
# 10012 Series([], Name: 2935, dtype: object)
# 10013 Series([], Name: 2936, dtype: object)
# 10014 Series([], Name: 2937, dtype: object)
# 10015 Series([], Name: 2938, dtype: object)
# 10016 Series([], Name: 2939, dtype: object)
# 10017 Series([], Name: 2940, dtype: object)
# 10018 Series([], Name: 2941, dtype: object)
# 10019 Series([], Name: 2942, dtype: object)
# 10020 Series([], Name: 2943, dtype: object)
# 10021 Series([], Name: 2944, dtype: object)
# 10022 Series([], Name: 2945, dtype: object)
# 10023 Series([], Name: 2946, dtype: object)
# 10024 Series([], Name: 2947, dtype: object)
# 10025 Series([], Name: 2948, dtype: object)
# 10026 Series([], Name: 2949, dtype: object)
# 10027 Series([], Name: 2950, dtype: object)
# 10028 Series([], Name: 2951, dtype: object)
# 10029 Series([], Name: 2952, dtype: object)
# 10030 Series([], Name: 2953, dtype: object)
# 10031 Series([], Name: 2954, dtype: object)
# 10032 Series([], Name: 2955, dtype: object)
# 10033 Series([], Name: 2956, dtype: object)
# 10034 Series([], Name: 2957, dtype: object)
# 10035 Series([], Name: 2958, dtype: object)
# 10036 Series([], Name: 2959, dtype: object)
# 10037 Series([], Name: 2960, dtype: object)
# 10038 Series([], Name: 2961, dtype: object)
# 10039 Series([], Name: 2962, dtype: object)
# 10040 Series([], Name: 2963, dtype: object)
# 10041 Series([], Name: 2964, dtype: object)
# 10042 Series([], Name: 2965, dtype: object)
# 10043 Series([], Name: 2966, dtype: object)
# 10044 Series([], Name: 2967, dtype: object)
# 10045 Series([], Name: 2968, dtype: object)
# 10046 Series([], Name: 2969, dtype: object)
# 10047 Series([], Name: 2970, dtype: object)
# 10048 Series([], Name: 2971, dtype: object)
# 10049 Series([], Name: 2972, dtype: object)
# 10050 Series([], Name: 2973, dtype: object)
# 10051 Series([], Name: 2974, dtype: object)
# 10052 Series([], Name: 2975, dtype: object)
# 10053 Series([], Name: 2976, dtype: object)
# 10054 Series([], Name: 2977, dtype: object)
# 10055 Series([], Name: 2978, dtype: object)
# 10056 Series([], Name: 2979, dtype: object)
# 10057 Series([], Name: 2980, dtype: object)
# 10058 Series([], Name: 2981, dtype: object)
# 10059 Series([], Name: 2982, dtype: object)
# 10060 Series([], Name: 2983, dtype: object)
# 10061 Series([], Name: 2984, dtype: object)
# 10062 Series([], Name: 2985, dtype: object)
# 10063 Series([], Name: 2986, dtype: object)
# 10064 Series([], Name: 2987, dtype: object)
# 10065 Series([], Name: 2988, dtype: object)
# 10066 Series([], Name: 2989, dtype: object)
# 10067 Series([], Name: 2990, dtype: object)
# 10068 Series([], Name: 2991, dtype: object)
# 10069 Series([], Name: 2992, dtype: object)
# 10070 Series([], Name: 2993, dtype: object)
# 10071 Series([], Name: 2994, dtype: object)
# 10072 Series([], Name: 2995, dtype: object)
# 10073 Series([], Name: 2996, dtype: object)
# 10074 Series([], Name: 2997, dtype: object)
# 10075 Series([], Name: 2998, dtype: object)
# 10076 Series([], Name: 2999, dtype: object)
# 10077 Series([], Name: 3000, dtype: object)
# 10078 Series([], Name: 3001, dtype: object)
# 10079 Series([], Name: 3002, dtype: object)
# 10080 Series([], Name: 3003, dtype: object)
# 10081 Series([], Name: 3004, dtype: object)
# 10082 Series([], Name: 3005, dtype: object)
# 10083 Series([], Name: 3006, dtype: object)
# 10084 Series([], Name: 3007, dtype: object)
# 10085 Series([], Name: 3008, dtype: object)
# 10086 Series([], Name: 3009, dtype: object)
# 10087 Series([], Name: 3010, dtype: object)
# 10088 Series([], Name: 3011, dtype: object)
# 10089 Series([], Name: 3012, dtype: object)
# 10090 Series([], Name: 3013, dtype: object)
# 10091 Series([], Name: 3014, dtype: object)
# 10092 Series([], Name: 3015, dtype: object)
# 10093 Series([], Name: 3016, dtype: object)
# 10094 Series([], Name: 3017, dtype: object)
# 10095 Series([], Name: 3018, dtype: object)
# 10096 Series([], Name: 3019, dtype: object)
# 10097 Series([], Name: 3020, dtype: object)
# 10098 Series([], Name: 3021, dtype: object)
# 10099 Series([], Name: 3022, dtype: object)
# 10100 Series([], Name: 3023, dtype: object)
# 10101 Series([], Name: 3024, dtype: object)
# 10102 Series([], Name: 3025, dtype: object)
# 10103 Series([], Name: 3026, dtype: object)
# 10104 Series([], Name: 3027, dtype: object)
# 10105 Series([], Name: 3028, dtype: object)
# 10106 Series([], Name: 3029, dtype: object)
# 10107 Series([], Name: 3030, dtype: object)
# 10108 Series([], Name: 3031, dtype: object)
# 10109 Series([], Name: 3032, dtype: object)
# 10110 Series([], Name: 3033, dtype: object)
# 10111 Series([], Name: 3034, dtype: object)
# 10112 Series([], Name: 3035, dtype: object)
# 10113 Series([], Name: 3036, dtype: object)
# 10114 Series([], Name: 3037, dtype: object)
# 10115 Series([], Name: 3038, dtype: object)
# 10116 Series([], Name: 3039, dtype: object)
# 10117 Series([], Name: 3040, dtype: object)
# 10118 Series([], Name: 3041, dtype: object)
# 10119 Series([], Name: 3042, dtype: object)
# 10120 Series([], Name: 3043, dtype: object)
# 10121 Series([], Name: 3044, dtype: object)
# 10122 Series([], Name: 3045, dtype: object)
# 10123 Series([], Name: 3046, dtype: object)
# 10124 Series([], Name: 3047, dtype: object)
# 10125 Series([], Name: 3048, dtype: object)
# 10126 Series([], Name: 3049, dtype: object)
# 10127 Series([], Name: 3050, dtype: object)
# 10128 Series([], Name: 3051, dtype: object)
# 10129 Series([], Name: 3052, dtype: object)
# 10130 Series([], Name: 3053, dtype: object)
# 10131 Series([], Name: 3054, dtype: object)
# 10132 Series([], Name: 3055, dtype: object)
# 10133 Series([], Name: 3056, dtype: object)
# 10134 Series([], Name: 3057, dtype: object)
# 10135 Series([], Name: 3058, dtype: object)
# 10136 Series([], Name: 3059, dtype: object)
# 10137 Series([], Name: 3060, dtype: object)
# 10138 Series([], Name: 3061, dtype: object)
# 10139 Series([], Name: 3062, dtype: object)
# 10140 Series([], Name: 3063, dtype: object)
# 10141 Series([], Name: 3064, dtype: object)
# 10142 Series([], Name: 3065, dtype: object)
# 10143 Series([], Name: 3066, dtype: object)
# 10144 Series([], Name: 3067, dtype: object)
# 10145 Series([], Name: 3068, dtype: object)
# 10146 Series([], Name: 3069, dtype: object)
# 10147 Series([], Name: 3070, dtype: object)
# 10148 Series([], Name: 3071, dtype: object)
# 10149 Series([], Name: 3072, dtype: object)
# 10150 Series([], Name: 3073, dtype: object)
# 10151 Series([], Name: 3074, dtype: object)
# 10152 Series([], Name: 3075, dtype: object)
# 10153 Series([], Name: 3076, dtype: object)
# 10154 Series([], Name: 3077, dtype: object)
# 10155 Series([], Name: 3078, dtype: object)
# 10156 Series([], Name: 3079, dtype: object)
# 10157 Series([], Name: 3080, dtype: object)
# 10158 Series([], Name: 3081, dtype: object)
# 10159 Series([], Name: 3082, dtype: object)
# 10160 Series([], Name: 3083, dtype: object)
# 10161 Series([], Name: 3084, dtype: object)
# 10162 Series([], Name: 3085, dtype: object)
# 10163 Series([], Name: 3086, dtype: object)
# 10164 Series([], Name: 3087, dtype: object)
# 10165 Series([], Name: 3088, dtype: object)
# 10166 Series([], Name: 3089, dtype: object)
# 10167 Series([], Name: 3090, dtype: object)
# 10168 Series([], Name: 3091, dtype: object)
# 10169 Series([], Name: 3092, dtype: object)
# 10170 Series([], Name: 3093, dtype: object)
# 10171 Series([], Name: 3094, dtype: object)
# 10172 Series([], Name: 3095, dtype: object)
# 10173 Series([], Name: 3096, dtype: object)
# 10174 Series([], Name: 3097, dtype: object)
# 10175 Series([], Name: 3098, dtype: object)
# 10176 Series([], Name: 3099, dtype: object)
# 10177 Series([], Name: 3100, dtype: object)
# 10178 Series([], Name: 3101, dtype: object)
# 10179 Series([], Name: 3102, dtype: object)
# 10180 Series([], Name: 3103, dtype: object)
# 10181 Series([], Name: 3104, dtype: object)
# 10182 Series([], Name: 3105, dtype: object)
# 10183 Series([], Name: 3106, dtype: object)
# 10184 Series([], Name: 3107, dtype: object)
# 10185 Series([], Name: 3108, dtype: object)
# 10186 Series([], Name: 3109, dtype: object)
# 10187 Series([], Name: 3110, dtype: object)
# 10188 Series([], Name: 3111, dtype: object)
# 10189 Series([], Name: 3112, dtype: object)
# 10190 Series([], Name: 3113, dtype: object)
# 10191 Series([], Name: 3114, dtype: object)
# 10192 Series([], Name: 3115, dtype: object)
# 10193 Series([], Name: 3116, dtype: object)
# 10194 Series([], Name: 3117, dtype: object)
# 10195 Series([], Name: 3118, dtype: object)
# 10196 Series([], Name: 3119, dtype: object)
# 10197 Series([], Name: 3120, dtype: object)
# 10198 Series([], Name: 3121, dtype: object)
# 10199 Series([], Name: 3122, dtype: object)
# 10200 Series([], Name: 3123, dtype: object)
# 10201 Series([], Name: 3124, dtype: object)
# 10202 Series([], Name: 3125, dtype: object)
# 10203 Series([], Name: 3126, dtype: object)
# 10204 Series([], Name: 3127, dtype: object)
# 10205 Series([], Name: 3128, dtype: object)
# 10206 Series([], Name: 3129, dtype: object)
# 10207 Series([], Name: 3130, dtype: object)
# 10208 Series([], Name: 3131, dtype: object)
# 10209 Series([], Name: 3132, dtype: object)
# 10210 Series([], Name: 3133, dtype: object)
# 10211 Series([], Name: 3134, dtype: object)
# 10212 Series([], Name: 3135, dtype: object)
# 10213 Series([], Name: 3136, dtype: object)
# 10214 Series([], Name: 3137, dtype: object)
# 10215 Series([], Name: 3138, dtype: object)
# 10216 Series([], Name: 3139, dtype: object)
# 10217 Series([], Name: 3140, dtype: object)
# 10218 Series([], Name: 3141, dtype: object)
# 10219 Series([], Name: 3142, dtype: object)
# 10220 Series([], Name: 3143, dtype: object)
# 10221 Series([], Name: 3144, dtype: object)
# 10222 Series([], Name: 3145, dtype: object)
# 10223 Series([], Name: 3146, dtype: object)
# 10224 Series([], Name: 3147, dtype: object)
# 10225 Series([], Name: 3148, dtype: object)
# 10226 Series([], Name: 3149, dtype: object)
# 10227 Series([], Name: 3150, dtype: object)
# 10228 Series([], Name: 3151, dtype: object)
# 10229 Series([], Name: 3152, dtype: object)
# 10230 Series([], Name: 3153, dtype: object)
# 10231 Series([], Name: 3154, dtype: object)
# 10232 Series([], Name: 3155, dtype: object)
# 10233 Series([], Name: 3156, dtype: object)
# 10234 Series([], Name: 3157, dtype: object)
# 10235 Series([], Name: 3158, dtype: object)
# 10236 Series([], Name: 3159, dtype: object)
# 10237 Series([], Name: 3160, dtype: object)
# 10238 Series([], Name: 3161, dtype: object)
# 10239 Series([], Name: 3162, dtype: object)
# 10240 Series([], Name: 3163, dtype: object)
# 10241 Series([], Name: 3164, dtype: object)
# 10242 Series([], Name: 3165, dtype: object)
# 10243 Series([], Name: 3166, dtype: object)
# 10244 Series([], Name: 3167, dtype: object)
# 10245 Series([], Name: 3168, dtype: object)
# 10246 Series([], Name: 3169, dtype: object)
# 10247 Series([], Name: 3170, dtype: object)
# 10248 Series([], Name: 3171, dtype: object)
# 10249 Series([], Name: 3172, dtype: object)
# 10250 Series([], Name: 3173, dtype: object)
# 10251 Series([], Name: 3174, dtype: object)
# 10252 Series([], Name: 3175, dtype: object)
# 10253 Series([], Name: 3176, dtype: object)
# 10254 Series([], Name: 3177, dtype: object)
# 10255 Series([], Name: 3178, dtype: object)
# 10256 Series([], Name: 3179, dtype: object)
# 10257 Series([], Name: 3180, dtype: object)
# 10258 Series([], Name: 3181, dtype: object)
# 10259 Series([], Name: 3182, dtype: object)
# 10260 Series([], Name: 3183, dtype: object)
# 10261 Series([], Name: 3184, dtype: object)
# 10262 Series([], Name: 3185, dtype: object)
# 10263 Series([], Name: 3186, dtype: object)
# 10264 Series([], Name: 3187, dtype: object)
# 10265 Series([], Name: 3188, dtype: object)
# 10266 Series([], Name: 3189, dtype: object)
# 10267 Series([], Name: 3190, dtype: object)
# 10268 Series([], Name: 3191, dtype: object)
# 10269 Series([], Name: 3192, dtype: object)
# 10270 Series([], Name: 3193, dtype: object)
# 10271 Series([], Name: 3194, dtype: object)
# 10272 Series([], Name: 3195, dtype: object)
# 10273 Series([], Name: 3196, dtype: object)
# 10274 Series([], Name: 3197, dtype: object)
# 10275 Series([], Name: 3198, dtype: object)
# 10276 Series([], Name: 3199, dtype: object)
# 10277 Series([], Name: 3200, dtype: object)
# 10278 Series([], Name: 3201, dtype: object)
# 10279 Series([], Name: 3202, dtype: object)
# 10280 Series([], Name: 3203, dtype: object)
# 10281 Series([], Name: 3204, dtype: object)
# 10282 Series([], Name: 3205, dtype: object)
# 10283 Series([], Name: 3206, dtype: object)
# 10284 Series([], Name: 3207, dtype: object)
# 10285 Series([], Name: 3208, dtype: object)
# 10286 Series([], Name: 3209, dtype: object)
# 10287 Series([], Name: 3210, dtype: object)
# 10288 Series([], Name: 3211, dtype: object)
# 10289 Series([], Name: 3212, dtype: object)
# 10290 Series([], Name: 3213, dtype: object)
# 10291 Series([], Name: 3214, dtype: object)
# 10292 Series([], Name: 3215, dtype: object)
# 10293 Series([], Name: 3216, dtype: object)
# 10294 Series([], Name: 3217, dtype: object)
# 10295 Series([], Name: 3218, dtype: object)
# 10296 Series([], Name: 3219, dtype: object)
# 10297 Series([], Name: 3220, dtype: object)
# 10298 Series([], Name: 3221, dtype: object)
# 10299 Series([], Name: 3222, dtype: object)
# 10300 Series([], Name: 3223, dtype: object)
# 10301 Series([], Name: 3224, dtype: object)
# 10302 Series([], Name: 3225, dtype: object)
# 10303 Series([], Name: 3226, dtype: object)
# 10304 Series([], Name: 3227, dtype: object)
# 10305 Series([], Name: 3228, dtype: object)
# 10306 Series([], Name: 3229, dtype: object)
# 10307 Series([], Name: 3230, dtype: object)
# 10308 Series([], Name: 3231, dtype: object)
# 10309 Series([], Name: 3232, dtype: object)
# 10310 Series([], Name: 3233, dtype: object)
# 10311 Series([], Name: 3234, dtype: object)
# 10312 Series([], Name: 3235, dtype: object)
# 10313 Series([], Name: 3236, dtype: object)
# 10314 Series([], Name: 3237, dtype: object)
# 10315 Series([], Name: 3238, dtype: object)
# 10316 Series([], Name: 3239, dtype: object)
# 10317 Series([], Name: 3240, dtype: object)
# 10318 Series([], Name: 3241, dtype: object)
# 10319 Series([], Name: 3242, dtype: object)
# 10320 Series([], Name: 3243, dtype: object)
# 10321 Series([], Name: 3244, dtype: object)
# 10322 Series([], Name: 3245, dtype: object)
# 10323 Series([], Name: 3246, dtype: object)
# 10324 Series([], Name: 3247, dtype: object)
# 10325 Series([], Name: 3248, dtype: object)
# 10326 Series([], Name: 3249, dtype: object)
# 10327 Series([], Name: 3250, dtype: object)
# 10328 Series([], Name: 3251, dtype: object)
# 10329 Series([], Name: 3252, dtype: object)
# 10330 Series([], Name: 3253, dtype: object)
# 10331 Series([], Name: 3254, dtype: object)
# 10332 Series([], Name: 3255, dtype: object)
# 10333 Series([], Name: 3256, dtype: object)
# 10334 Series([], Name: 3257, dtype: object)
# 10335 Series([], Name: 3258, dtype: object)
# 10336 Series([], Name: 3259, dtype: object)
# 10337 Series([], Name: 3260, dtype: object)
# 10338 Series([], Name: 3261, dtype: object)
# 10339 Series([], Name: 3262, dtype: object)
# 10340 Series([], Name: 3263, dtype: object)
# 10341 Series([], Name: 3264, dtype: object)
# 10342 Series([], Name: 3265, dtype: object)
# 10343 Series([], Name: 3266, dtype: object)
# 10344 Series([], Name: 3267, dtype: object)
# 10345 Series([], Name: 3268, dtype: object)
# 10346 Series([], Name: 3269, dtype: object)
# 10347 Series([], Name: 3270, dtype: object)
# 10348 Series([], Name: 3271, dtype: object)
# 10349 Series([], Name: 3272, dtype: object)
# 10350 Series([], Name: 3273, dtype: object)
# 10351 Series([], Name: 3274, dtype: object)
# 10352 Series([], Name: 3275, dtype: object)
# 10353 Series([], Name: 3276, dtype: object)
# 10354 Series([], Name: 3277, dtype: object)
# 10355 Series([], Name: 3278, dtype: object)
# 10356 Series([], Name: 3279, dtype: object)
# 10357 Series([], Name: 3280, dtype: object)
# 10358 Series([], Name: 3281, dtype: object)
# 10359 Series([], Name: 3282, dtype: object)
# 10360 Series([], Name: 3283, dtype: object)
# 10361 Series([], Name: 3284, dtype: object)
# 10362 Series([], Name: 3285, dtype: object)
# 10363 Series([], Name: 3286, dtype: object)
# 10364 Series([], Name: 3287, dtype: object)
# 10365 Series([], Name: 3288, dtype: object)
# 10366 Series([], Name: 3289, dtype: object)
# 10367 Series([], Name: 3290, dtype: object)
# 10368 Series([], Name: 3291, dtype: object)
# 10369 Series([], Name: 3292, dtype: object)
# 10370 Series([], Name: 3293, dtype: object)
# 10371 Series([], Name: 3294, dtype: object)
# 10372 Series([], Name: 3295, dtype: object)
# 10373 Series([], Name: 3296, dtype: object)
# 10374 Series([], Name: 3297, dtype: object)
# 10375

# %%
mvocat['quality_index'] = quality_index
mvocat.to_csv('MVOE_CATALOG_QC.csv')

# %%
mvocat.mainclass.value_counts()
# Out:
# LV    40576
# R      9801
# D      2234
# Name: mainclass, dtype: int64

# %%
mvocat.subclass.value_counts()
# Out:
# t    15796
# _    11967
# h     7555
# r     7211
# l     4761
# n     4505
# m      576
# x      171
# e       69
# Name: subclass, dtype: int64

# %%
LVcat = mvocat.loc[mvocat.mainclass == 'LV']
LVcat.subclass.value_counts()
# Out:
# t    15753
# h     7530
# r     7211
# l     4761
# n     4505
# m      576
# x      171
# e       69
# Name: subclass, dtype: int64

# %%
len(LVcat.wavfilepath.unique())
# Out:
# 1254

# %%
import matplotlib.pyplot as plt
